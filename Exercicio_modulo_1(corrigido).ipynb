# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandaSantos225/FernandaSantos225/blob/main/Exercicio_modulo_1(corrigido).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá mundo!")
# Out:
# Olá mundo!

# %% [markdown]
# ![IMG_1455.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket médio abaixo:
#
# <br>
#
# | Dia   | Valor Total Vendas | Qtd Total Vendas | Ticket Medio |
# |-------|--------------------|------------------|--------------|
# | 19/01 | (A)                | 3                | 320.52       |
# | 20/01 | 834.47             | (B)              | 119.21       |
# | 23/01 | 15378.12           | 5                | (C)          |

# %% [markdown]
# Ticket medio 19/01

# %%
qtv_19=3
tm_19=320.52
vtv_19=tm_19*qtv_19
print(vtv_19)
# Out:
# 961.56

# %% [markdown]
# Ticket medio 20/01

# %%
vtv_20=834.47
tm_20=119.21
qtv_20=vtv_20/tm_20
print(qtv_20)
# Out:
# 7.000000000000001

# %% [markdown]
# Ticket medio de 23/01

# %%
vt_23=15378.12
qtv_23=5
tm_23=vt_23/qtv_23
print(tm_23)
# Out:
# 3075.6240000000003

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Strings

# %% [markdown]
# Aplique três métodos distintos na *string* abaixo, você pode conferir alguns métodos neste [link](https://www.w3schools.com/python/python_ref_string.asp):

# %%
nome_vendedor = "Joaquim"
setor = "vendas"

apresentacao = f"Olá, meu nome é {nome_vendedor} do setor de {setor}"
print(apresentacao)

cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

print(cancao.capitalize())
print(cancao.upper())
print(cancao.replace('roda', 'gira'))
# Out:
# Olá, meu nome é Joaquim do setor de vendas
# Roda mundo, roda gigante, roda moinho, roda pião.
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.
# Roda mundo, gira gigante, gira moinho, gira pião.

# %%
#substituicao: string.replace(antigo,novo)
print(setor.replace("vendas","venda"))
# Out:
# venda

# %%
valor=250
print(type(valor))

valor=str(valor)
print(type(valor))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Extraia da string abaixo o valor da taxa **selic** na variável `selic` e o valor do **ano** na variavel `ano`. Imprima os valores na tela.

# %%
texto = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.  Em 2015, a taxa básica de juros chegou a 14,25%.'
selic = texto[12:17]
ano = texto[74:78]
print(selic)
print(ano)
# Out:
# 2,75%
# 2015

# %% [markdown]
# ---

# %% [markdown]
# ## 4\. Booleanos

# %% [markdown]
# Utilize a tabela da verdade para responder: qual o valor da variável x?

# %%
a = False
b = True

x = not a & b

print(x)
# Out:
# True
